# %%
import numpy as np
import matplotlib.pyplot as plt
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.112

# %%
# [作業1]

def mean_square_error(y, yp):
    mse = MSE = sum(pow((y - yp),2)) / len(y)
    return mse
MSE = mean_square_error(y,y_hat)
print("The Mean square error is %.3f" % (MSE))
# Out:
# The Mean square error is 217.191

# %%
# [作業2]

請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：

1. 你選的這組資料為何重要

Ａ：在之後的工作上也可以用得上，幫助公司利用數據分析預測風險及市場方向

2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)

Ａ：俄國最大的市場調查公司1C-Company，提供每天的紀錄資料

3. 蒐集而來的資料型態為何

Ａ：sales_train.csv - the training set. Daily historical data from January 2013 to October 2015.
   test.csv - the test set. You need to forecast the sales for these shops and products for November 2015.
   sample_submission.csv - a sample submission file in the correct format.
   items.csv - supplemental information about the items/products.
   item_categories.csv  - supplemental information about the items categories.
   shops.csv- supplemental information about the shops.
   
   CSV的紀錄型態

4. 這組資料想解決的問題如何評估

Ａ：利用統計學上的Root Mean Square Deviation找出差異性及方向，預測之後的走向

# %%
# [作業3]

想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)

Ａ：提升業績主要來自客戶，客戶需再細分性別及年齡，因為我經營的是自由載客，需在分載客的地區，
   我的假設是如需提升業績，需定義在一天的時間都必須載到客戶，先分析地區載客哪裡最需要車隊，再來是時間例如上班時，
   天氣下雨或熱到不行，路線挑大眾運輸工具比較到不了的

2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)

Ａ：氣象局的天氣預報，交通局的大眾運輸路線

3. 蒐集而來的資料型態為何

Ａ：CSV歷史數據資料

4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

Ａ：請我經營的車隊去跑一次設定的路線，以一個月為準來驗證對照去年同期的數字．
